# %% [markdown]
# # Обучаем первые классификаторы в sklearn

# %% [markdown]
# ### Данные

# %% [markdown]
# По данным характеристикам молекулы требуется определить, будет ли дан биологический ответ (biological response).
#
# Для демонстрации используется обучающая выборка из исходных данных bioresponse.csv, файл с данными прилагается.

# %% [markdown]
# ### Возьмём данные с семинара

# %%
import pandas as pd

bioresponse = pd.read_csv('../seminar01/bioresponse.csv', header=0, sep=',')

# %%
print(bioresponse.shape)
bioresponse.head(5)
# Out:
# (3751, 1777)
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...    D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...        0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...        1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...        0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...        0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...        0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %%
y = bioresponse.Activity.values

# %%
X = bioresponse.iloc[:, 1:]

# %% [markdown]
# ## Вспомним разные модели с семинара

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.model_selection import cross_val_score

# %%
models = [
    LogisticRegression(),
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    LinearSVC(),
    RandomForestClassifier(n_estimators=100), 
    GradientBoostingClassifier(n_estimators=100)
]

for model in models:
    # %time print(model, '\nAccuracy:', cross_val_score(model, X, y, cv=5).mean())
    print()
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Accuracy: 0.7518013365357094
# CPU times: user 2.92 s, sys: 2.12 s, total: 5.05 s
# Wall time: 2.4 s
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')
# Accuracy: 0.7480751086372301
# CPU times: user 33.3 s, sys: 698 ms, total: 34 s
# Wall time: 33.4 s
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Accuracy: 0.7238045057265288
# CPU times: user 3.83 s, sys: 174 ms, total: 4 s
# Wall time: 4 s
#
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)
# Accuracy: 0.7406041610740642
# CPU times: user 7.46 s, sys: 2.11 s, total: 9.57 s
# Wall time: 6.9 s
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Accuracy: 0.797919435471589
# CPU times: user 7.03 s, sys: 615 ms, total: 7.65 s
# Wall time: 6.99 s
#
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)
# Accuracy: 0.7835279498570961
# CPU times: user 54.2 s, sys: 240 ms, total: 54.5 s
# Wall time: 54.5 s

# %% [markdown]
# # Задание
#
# Используя класс для перебора параметров по сетке [GridSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html), напишите перебор параметров LogisticRegression:
# - Параметр C по степеням 10 от -5 до +5
# - Параметр max_iter от 100 до 500 включительно с шагом 100
# - Параметр penalty либо 'l1' либо 'l2'
# - Параметр random_state обязательно 42
# - Параметр fit_intercept либо False либо True

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
param_grid = {
    'C':np.logspace(-5, 5, 11),
    'max_iter':np.arange(100,501,100),
    'penalty':['l1', 'l2'],
    'random_state':[42],
    'fit_intercept':[False, True]
}

print(round(GridSearchCV(
   LogisticRegression(),  param_grid,verbose=2, cv=5, n_jobs=-1
).fit(X, y).best_score_, 4))
# Out:
# Fitting 5 folds for each of 220 candidates, totalling 1100 fits
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.1s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.6s
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.4s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=1e-05, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.4s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=1e-05, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.1s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.4s
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   18.9s
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.4s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.1s
# [CV]  C=0.0001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.0001, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l1, random_state=42, total=   0.1s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.1s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total=   0.5s
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.4s
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.1s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.5s
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.5s
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total=   0.7s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.4s
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.4s
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.4s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.4s
# [CV]  C=0.001, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=   0.2s
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV] C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=0.001, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total=   0.3s
# [CV] C=0.001, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# ...
# [CV]  C=10000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=40.2min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42
# [CV]  C=10000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=40.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total= 1.5min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=15.8min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=15.4min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=10000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=41.1min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=10000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=41.3min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=15.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=15.5min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=200, penalty=l1, random_state=42, total=15.8min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=24.4min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=23.7min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=24.0min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=24.3min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=300, penalty=l1, random_state=42, total=24.5min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=32.2min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=32.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=33.0min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total= 1.5min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l2, random_state=42, total= 1.6min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=32.6min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total= 6.3min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=400, penalty=l1, random_state=42, total=32.9min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total= 6.3min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total= 7.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=  39.0s
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=  46.1s
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total= 7.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=  36.1s
# [CV] C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=  31.9s
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l2, random_state=42, total=  35.0s
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=41.6min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=100, penalty=l1, random_state=42, total= 7.1min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=40.6min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=41.5min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total= 1.7min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total= 1.4min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total= 1.9min
# [CV] C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=15.1min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=14.9min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=41.4min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=False, max_iter=500, penalty=l1, random_state=42, total=41.4min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=15.7min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=15.6min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=200, penalty=l1, random_state=42, total=15.9min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total= 2.1min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total= 1.7min
# [CV] C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total= 1.5min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=23.5min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=23.3min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=24.2min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=24.3min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=300, penalty=l1, random_state=42, total=24.2min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total= 1.4min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total= 2.1min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total= 1.8min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=32.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=31.9min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=32.8min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total= 1.7min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total= 1.4min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total= 2.0min
# [CV] C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l2, random_state=42, total= 1.8min
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=32.2min
# [CV]  C=100000.0, fit_intercept=True, max_iter=400, penalty=l1, random_state=42, total=32.1min
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=36.1min
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=34.7min
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=35.0min
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=26.7min
# [CV]  C=100000.0, fit_intercept=True, max_iter=500, penalty=l1, random_state=42, total=28.5min
# [Parallel(n_jobs=-1)]: Done 1100 out of 1100 | elapsed: 478.5min finished
# 0.7627

# %% [markdown]
# Полученное число введите в форму для ответов

# %%
GridSearchCV()
